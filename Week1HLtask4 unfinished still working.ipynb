# %%
#a motorbike costs £2000 and loses 10%of it's value every year. Using a loop, print the value of the bike every following year until it falls below £1000
#main clculation
#loop command

from math import *
bike_cost= 2000
while bike_cost >1000:
    print(str(bike_cost- (bike_cost/100)*10))
# Out:
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# 1800.0
# 2000
# ...

# %%
for y in range [x, x2, x3, x4]
x2 = x-x*0.01
x3 = x2-x2*0.01
x4 = x3-x3*0.01
print y
while y>1000
